# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import sys
import os

sys.path.append('/notebooks/carputils')
sys.path.append('/notebooks/examples')

os.environ['CARP_LICENSE'] = '/usr/local/lib/carpentry/license.bin'

# %%
! cat /notebooks/examples/tutorials/02_EP_tissue/01_basic_usage/run.py
# Out:
# #!/usr/bin/env python
#
# r"""
# Overview
# ...
#
# This tutorial introduces to the basics of using the carpentry executable
# for simulating EP at the tissue and organ scale.
# Details on how to inquire input parameters are provided in the :ref:`carpentry <carpentry>` section
# of the manual.
#
# In absence of pacemaker currents electrical stimulus currents must be supplied in order to
# depolarize tissue above the threshold to elicit a propagated action potential.
# The simplest way of initiating a propagating action potential is the use of a transmembrane stimulus, :math:`I_{\mathrm{tr}}`.
# According to the definition in CARPentry supplying a positive :math:`I_{\mathrm{tr}}` depolarizes the tissue,
# a negative :math:`I_{\mathrm{tr}}` hyperpolarizes the tissue.
#
#
# Experimental setup
# ...
#
# To introduce definition and usage of transmembrane stimulus currents in CARPentry a simple experiment
# ...

# %%
! cat /notebooks/examples/tutorials/05_pre_post_processing/06_UVC_bullseye/run.py
# Out:
# #!/usr/bin/env python
#
# """
#
# .. _Karli Gillette: karli.gillette@medunigraz.at
#
# .. warning::
#
#     This tutorial cannot be run without access to the model architecture code located in experiments_market.
#     Please contact `Karli Gillette`_  for more information. If you already have access, please ensure that your environment
#     is set properly!
#
# Introduction
# ...
#
# UVC coordinates can be used for the construction of a clinically based bullseye plot. The bullseye decomposes the left
# ventricle into 17 quadrants based on regional aspects of the left ventricle (LV) relating to functionality
# and myocardial perfusion. In general, the bullseye code described in this tutorial generates the following quadrants
# on an LV model based on the rotational (phi) and apico-basal (Z) coordinates of the UVC:
#
# .. figure:: /images/05_pre_post_processing_06_UVC_bullseye_BE.png
#     :width: 75 %
#     :align: center
#
#
# Implementation
# ...
#
# To run this simulation, simply use:
#
# ...

# %%
from datetime import date
from carputils import settings
from carputils import tools
from carputils import mesh
from carputils import testing

# %%
mesh.Ellipsoid?

# %%
geom = mesh.Ellipsoid(r_a=25, r_b=25, r_c=35)

# %%
meshname = geom.generate_carp('meshes/test')
