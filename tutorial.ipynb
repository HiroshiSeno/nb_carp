# %% [markdown]
# ## import & 環境設定 (ここでやってます...)

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import sys
import os

sys.path.append('/notebooks/carputils')
sys.path.append('/notebooks/examples')

os.environ['CARP_LICENSE'] = '/usr/local/lib/carpentry/license.bin'

# %% [markdown]
# ## sample code (02_EP_tissue/01_basic_usage)
# - 3次元上でblock状のmeshを作成(10 x 1 x 0.2 mm)
# - 心筋繊維走行を設定．(設定の詳細はよくわかっていない)
# - "basic.par"からcommandを読み込む．commandでは刺激条件やtime stepを設定可能．
# - "job.carp(cmd)"でcommandを実行
# - meshalyzerはdisplayを開こうとするため，実行できていない．

# %%
# %run -i ../examples/tutorials/02_EP_tissue/01_basic_usage/run.py --duration 500 --S1-strength 20. --S1-dur 15
# Out:
# ======================================================================
# SETTINGS SUMMARY
# ======================================================================
# Executables
# ----------------------------------------------------------------------
#    CARP:            /usr/local/lib/carpentry/carp.petsc.pt
#    MESHER:          /usr/local/lib/carpentry/mesher
#    FSM:             < NOT FOUND >
#    BENCH:           /usr/local/lib/carpentry/bench
#    GLINTERPOLATE:   /usr/local/lib/carpentry/GlInterpolate
#    GLGRADIENT:      /usr/local/lib/carpentry/GlGradient
#    GLELEMCENTERS:   /usr/local/lib/carpentry/GlElemCenters
#    GLMESHCONVERT:   /usr/local/lib/carpentry/GlMeshConvert
#    GLVTKCONVERT:    /usr/local/lib/carpentry/GlVTKConvert
#    GLTRANSFER:      /usr/local/lib/carpentry/GlTransfer
#    GLRULEFIBERS:    /usr/local/lib/carpentry/GlRuleFibers
#    ELLIPTICSOLVER:  < NOT FOUND >
#    PARABOLICSOLVER: < NOT FOUND >
#    ADJOINTSOLVER:   < NOT FOUND >
#    GLFILAMENT:      /usr/local/lib/carpentry/GlFilament
#    GLIGBPROCESS:    /usr/local/lib/carpentry/GlIGBProcess
#    SURFACEMESH:     < NOT FOUND >
#    GLSURFACECONVERT: /usr/local/lib/carpentry/GlSurfaceConvert
#    MESHTOOL:        /usr/local/lib/carpentry/meshtool
#    ELASTICITY:      < NOT FOUND >
#    FLUIDSOLVE:      < NOT FOUND >
#    CVSTOOL:         < NOT FOUND >
#    IGBHEAD:         /usr/local/lib/carpentry/igbhead
#    IGBOPS:          /usr/local/lib/carpentry/igbops
#    IGBEXTRACT:      /usr/local/lib/carpentry/igbextract
#    IGBAPD:          /usr/local/lib/carpentry/igbapd
#    IGBDFT:          /usr/local/lib/carpentry/igbdft
#    MESHALYZER:      < NOT FOUND >
#    MODH5:           < NOT FOUND >
#    DATH5:           < NOT FOUND >
#    LIMPETGUI:       < NOT FOUND >
#    SV2H5B:          < NOT FOUND >
#    SV2H5T:          < NOT FOUND >
#    EKBATCH:         < NOT FOUND >
#    EKSOLVE:         < NOT FOUND >
#    LIMPETFE:        < NOT FOUND >
#    TUNECV:          < NOT FOUND >
#    BEMECG:          < NOT FOUND >
# ----------------------------------------------------------------------
# Command Line Options
# ----------------------------------------------------------------------
#    NP:        1
#    BUILD:     CPU
#    FLAVOR:    pt
#    DRY:       False
#    VISUALIZE: False
# ----------------------------------------------------------------------
# Solver Option Files
# ----------------------------------------------------------------------
#    Parabolic: /notebooks/carputils/carputils/resources/options/pt_para_amg
#    Elliptic:  /notebooks/carputils/carputils/resources/options/pt_ell_amg
#    Purkinje:  /notebooks/carputils/carputils/resources/petsc_options/petsc_purk_gmres_opts
# ----------------------------------------------------------------------
# System Settings
# ----------------------------------------------------------------------
#    Python:    2.7.13
# ----------------------------------------------------------------------
# Email: sb.h.h78181@gmail.com
# ======================================================================
#
# ()
# Requested mesh already exists, skipping generation.
# mkdir -p 2019-06-27_basic_500.0
#
# #---------------------------------------------------------------------
# #          Launching CARP Simulation 2019-06-27_basic_500.0
# #---------------------------------------------------------------------
#
# /usr/local/lib/carpentry/carp.petsc.pt \
#   +F basic.par \
#   +F /notebooks/carputils/carputils/resources/options/pt_ell_amg \
#   +F /notebooks/carputils/carputils/resources/options/pt_para_amg \
#   -ellip_use_pt 1 \
#   -parab_use_pt 1 \
#   -purk_use_pt 0 \
#   -ellip_options_file /notebooks/carputils/carputils/resources/options/pt_ell_amg \
#   -parab_options_file /notebooks/carputils/carputils/resources/options/pt_para_amg \
#   -purk_options_file /notebooks/carputils/carputils/resources/petsc_options/petsc_purk_gmres_opts \
#   -vectorized_fe 0 \
#   -simID 2019-06-27_basic_500.0 \
#   -meshname meshes/2019-06-25_OFvsKLwHmE/block \
#   -dt 25 \
#   -tend 500.0 \
#   -num_stim 1 \
#   -stimulus[0].name S1 \
#   -stimulus[0].stimtype 0 \
#   -stimulus[0].strength 20.0 \
#   -stimulus[0].duration 15.0 \
#   -stimulus[0].x0 -5050.0 \
#   -stimulus[0].xd 100.0 \
#   -stimulus[0].y0 -550.0 \
#   -stimulus[0].yd 1100.0 \
#   -stimulus[0].z0 -150.0 \
#   -stimulus[0].zd 300.0
#
# Found license file path: /usr/local/lib/carpentry/license.bin
# L2 : Output directory exists: 2019-06-27_basic_500.0
#
#
# L2 : pt requires proper DD: setting pstrat = 1
# L2 : pt requires proper DD: setting pstrat_i = 1
#
# Reading model meshes/2019-06-25_OFvsKLwHmE/block
# Start reading element file meshes/2019-06-25_OFvsKLwHmE/block.elem.
# #extracellular elements: 10000
# Element file read in 0.0241 seconds.
# Start reading points file meshes/2019-06-25_OFvsKLwHmE/block.pts.
# #extracellular nodes:    3333
# Mesh nodal points file read in 0.00226 seconds.
# Reading model meshes/2019-06-25_OFvsKLwHmE/block done in 0.0266 seconds.
# L1 : Switching to scatter-based domain mapper.
#
# Intra Element list memory usage (min/max/global)   0.9   0.9   0.9 MByte.
# Intra Node list memory usage    (min/max/global)   0.1   0.1   0.1 MByte.
# Intra Surface list memory usage (min/max/global)   0.0   0.0   0.0 MByte.
# L1 : Memory allocated for scatter based mapping ignored.
#
# Mapping memory usage            (min/max/global)   0.0   0.0   0.0 MByte.
# Permute memory usage (intra)    (min/max/global)   0.0   0.0   0.0 MByte.
# Intra Element list memory usage (min/max/global)   0.9   0.9   0.9 MByte.
# Intra Node list memory usage    (min/max/global)   0.1   0.1   0.1 MByte.
# Intra Surface list memory usage (min/max/global)   0.0   0.0   0.0 MByte.
# L1 : Memory allocated for scatter based mapping ignored.
#
# Mapping memory usage            (min/max/global)   0.0   0.0   0.0 MByte.
# Permute memory usage (intra)    (min/max/global)   0.0   0.0   0.0 MByte.
#
# Build model time: 0.0
#
# Grid "intracellular electric":
# Number of elements (Global/Locally Stored): 10000/10000
# Number of nodes (Global/Locally Stored): 3333/3333
# Optimal number of processes estimate: 0
#
#
#
# Setting up ionic models and plugins
# -----------------------------------
#
# Assigning IMPS to tagged regions:
#
# .
#
#
#
#
# setup_stimulus(...)[0]
#
# PT: WARNING Accumulation buffer not passed to PT.
# PT: This means that vectorized FEM is disabled or broken. Will allocate own buffer.
# Building intracellular electric stiffness matrix in standard mode.
# Building intracellular electric stiffness matrix done in 0.067 seconds.
# Building intracellular electric lumped mass matrix in standard mode.
# Building intracellular electric lumped mass matrix done in 0.004 seconds.
# PT: parabolic preconditioner Jacobi
# PT: parabolic solver CG
# Initializing parabolic solver in 0.00017 seconds.
#
#
# Affected Stimulus Volumes
# Type           (          Name) [Stimulus  ID]: Vol um^3 ( Vol mm^3 )
# -------------- ---------------- -------------- --------- ------------
# trans I        (S1            ) [Stimulus   0]:    1e+07 (     0.01 )
#
#
#
#
#
# Current Injecting electrodes
# Type           (          Name) [ID]: Total [uA] Density
# -------------- ---------------- ----- ---------- --------------------
# trans I        (S1            ) [ 0]:       0.28         20 [uA/cm^2]
#
#
#
#
# IO initialized for grid intracellular electric in write mode for 3333 data.
#
# Electrics setup time: 0.1
#
#
# initialization time (s): 0
#
# PROG	----- 	----	-----	-------|
# time	%%comp	time	ctime	  ETA  |
# 0.00	0.0	0.0	0.0	0:00:00
# 1.00	0.2	0.0	0.0	0:00:20
# 2.00	0.4	0.0	0.1	0:00:21
# 3.00	0.6	0.0	0.1	0:00:20
# 4.00	0.8	0.0	0.2	0:00:20
# 5.00	1.0	0.0	0.2	0:00:20
# 6.00	1.2	0.0	0.3	0:00:20
# 7.00	1.4	0.0	0.3	0:00:20
# 8.00	1.6	0.0	0.3	0:00:20
# 9.00	1.8	0.0	0.4	0:00:20
# 10.00	2.0	0.0	0.4	0:00:20
# 11.00	2.2	0.0	0.5	0:00:20
# 12.00	2.4	0.0	0.5	0:00:20
# 13.00	2.6	0.0	0.6	0:00:20
# 14.00	2.8	0.0	0.6	0:00:20
# 15.00	3.0	0.0	0.6	0:00:19
# 16.00	3.2	0.0	0.6	0:00:19
# 17.00	3.4	0.0	0.7	0:00:18
# 18.00	3.6	0.0	0.7	0:00:18
# 19.00	3.8	0.0	0.7	0:00:17
# 20.00	4.0	0.0	0.7	0:00:17
# 21.00	4.2	0.0	0.7	0:00:16
# 22.00	4.4	0.0	0.8	0:00:16
# 23.00	4.6	0.0	0.8	0:00:16
# 24.00	4.8	0.0	0.8	0:00:15
# 25.00	5.0	0.0	0.8	0:00:15
# 26.00	5.2	0.0	0.8	0:00:15
# 27.00	5.4	0.0	0.9	0:00:14
# 28.00	5.6	0.0	0.9	0:00:14
# 29.00	5.8	0.0	0.9	0:00:14
# 30.00	6.0	0.0	0.9	0:00:14
# 31.00	6.2	0.0	0.9	0:00:14
# 32.00	6.4	0.0	0.9	0:00:13
# 33.00	6.6	0.0	1.0	0:00:13
# 34.00	6.8	0.0	1.0	0:00:13
# 35.00	7.0	0.0	1.0	0:00:13
# 36.00	7.2	0.0	1.0	0:00:13
# 37.00	7.4	0.0	1.0	0:00:13
# 38.00	7.6	0.0	1.1	0:00:12
# 39.00	7.8	0.0	1.1	0:00:12
# 40.00	8.0	0.0	1.1	0:00:12
# 41.00	8.2	0.0	1.1	0:00:12
# 42.00	8.4	0.0	1.1	0:00:12
# 43.00	8.6	0.0	1.1	0:00:12
# 44.00	8.8	0.0	1.2	0:00:12
# 45.00	9.0	0.0	1.2	0:00:11
# 46.00	9.2	0.0	1.2	0:00:11
# 47.00	9.4	0.0	1.2	0:00:11
# 48.00	9.6	0.0	1.2	0:00:11
# 49.00	9.8	0.0	1.3	0:00:11
# 50.00	10.0	0.0	1.3	0:00:11
# 51.00	10.2	0.0	1.3	0:00:11
# 52.00	10.4	0.0	1.3	0:00:11
# 53.00	10.6	0.0	1.3	0:00:11
# 54.00	10.8	0.0	1.3	0:00:11
# 55.00	11.0	0.0	1.4	0:00:10
# 56.00	11.2	0.0	1.4	0:00:10
# 57.00	11.4	0.0	1.4	0:00:10
# 58.00	11.6	0.0	1.4	0:00:10
# 59.00	11.8	0.0	1.4	0:00:10
# 60.00	12.0	0.0	1.4	0:00:10
# 61.00	12.2	0.0	1.5	0:00:10
# 62.00	12.4	0.0	1.5	0:00:10
# 63.00	12.6	0.0	1.5	0:00:10
# 64.00	12.8	0.0	1.5	0:00:10
# 65.00	13.0	0.0	1.5	0:00:10
# 66.00	13.2	0.0	1.5	0:00:10
# 67.00	13.4	0.0	1.6	0:00:10
# 68.00	13.6	0.0	1.6	0:00:10
# 69.00	13.8	0.0	1.6	0:00:09
# 70.00	14.0	0.0	1.6	0:00:09
# 71.00	14.2	0.0	1.6	0:00:09
# 72.00	14.4	0.0	1.6	0:00:09
# 73.00	14.6	0.0	1.7	0:00:09
# 74.00	14.8	0.0	1.7	0:00:09
# 75.00	15.0	0.0	1.7	0:00:09
# 76.00	15.2	0.0	1.7	0:00:09
# 77.00	15.4	0.0	1.7	0:00:09
# 78.00	15.6	0.0	1.7	0:00:09
# 79.00	15.8	0.0	1.8	0:00:09
# 80.00	16.0	0.0	1.8	0:00:09
# 81.00	16.2	0.0	1.8	0:00:09
# 82.00	16.4	0.0	1.8	0:00:09
# 83.00	16.6	0.0	1.8	0:00:09
# 84.00	16.8	0.0	1.9	0:00:09
# 85.00	17.0	0.0	1.9	0:00:09
# 86.00	17.2	0.0	1.9	0:00:09
# 87.00	17.4	0.0	1.9	0:00:09
# 88.00	17.6	0.0	1.9	0:00:09
# 89.00	17.8	0.0	2.0	0:00:09
# 90.00	18.0	0.0	2.0	0:00:09
# 91.00	18.2	0.0	2.0	0:00:08
# 92.00	18.4	0.0	2.0	0:00:08
# 93.00	18.6	0.0	2.0	0:00:08
# 94.00	18.8	0.0	2.0	0:00:08
# 95.00	19.0	0.0	2.1	0:00:08
# 96.00	19.2	0.0	2.1	0:00:08
# 97.00	19.4	0.0	2.1	0:00:08
# 98.00	19.6	0.0	2.1	0:00:08
# 99.00	19.8	0.0	2.1	0:00:08
# 100.00	20.0	0.0	2.2	0:00:08
# 101.00	20.2	0.0	2.2	0:00:08
# 102.00	20.4	0.0	2.2	0:00:08
# 103.00	20.6	0.0	2.2	0:00:08
# 104.00	20.8	0.0	2.3	0:00:08
# 105.00	21.0	0.0	2.3	0:00:08
# 106.00	21.2	0.0	2.3	0:00:08
# 107.00	21.4	0.0	2.3	0:00:08
# 108.00	21.6	0.0	2.3	0:00:08
# 109.00	21.8	0.0	2.4	0:00:08
# 110.00	22.0	0.0	2.4	0:00:08
# 111.00	22.2	0.0	2.4	0:00:08
# 112.00	22.4	0.0	2.4	0:00:08
# 113.00	22.6	0.0	2.4	0:00:08
# 114.00	22.8	0.0	2.4	0:00:08
# 115.00	23.0	0.0	2.5	0:00:08
# 116.00	23.2	0.0	2.5	0:00:08
# 117.00	23.4	0.0	2.5	0:00:08
# 118.00	23.6	0.0	2.6	0:00:08
# 119.00	23.8	0.0	2.6	0:00:08
# 120.00	24.0	0.0	2.6	0:00:08
# 121.00	24.2	0.0	2.7	0:00:08
# 122.00	24.4	0.0	2.7	0:00:08
# 123.00	24.6	0.0	2.7	0:00:08
# 124.00	24.8	0.0	2.7	0:00:08
# 125.00	25.0	0.0	2.8	0:00:08
# 126.00	25.2	0.0	2.8	0:00:08
# 127.00	25.4	0.0	2.8	0:00:08
# 128.00	25.6	0.0	2.8	0:00:08
# 129.00	25.8	0.0	2.9	0:00:08
# 130.00	26.0	0.0	2.9	0:00:08
# 131.00	26.2	0.0	2.9	0:00:08
# 132.00	26.4	0.0	3.0	0:00:08
# 133.00	26.6	0.0	3.0	0:00:08
# 134.00	26.8	0.0	3.0	0:00:08
# 135.00	27.0	0.0	3.0	0:00:08
# 136.00	27.2	0.0	3.1	0:00:08
# 137.00	27.4	0.0	3.1	0:00:08
# 138.00	27.6	0.0	3.1	0:00:08
# 139.00	27.8	0.0	3.1	0:00:08
# 140.00	28.0	0.0	3.2	0:00:08
# 141.00	28.2	0.0	3.2	0:00:08
# 142.00	28.4	0.0	3.2	0:00:08
# 143.00	28.6	0.0	3.3	0:00:08
# 144.00	28.8	0.0	3.3	0:00:08
# 145.00	29.0	0.0	3.3	0:00:08
# 146.00	29.2	0.0	3.4	0:00:08
# 147.00	29.4	0.0	3.4	0:00:08
# 148.00	29.6	0.0	3.4	0:00:08
# 149.00	29.8	0.0	3.4	0:00:08
# 150.00	30.0	0.0	3.4	0:00:07
# 151.00	30.2	0.0	3.4	0:00:07
# 152.00	30.4	0.0	3.5	0:00:07
# 153.00	30.6	0.0	3.5	0:00:07
# 154.00	30.8	0.0	3.5	0:00:07
# 155.00	31.0	0.0	3.5	0:00:07
# 156.00	31.2	0.0	3.5	0:00:07
# 157.00	31.4	0.0	3.6	0:00:07
# 158.00	31.6	0.0	3.6	0:00:07
# 159.00	31.8	0.0	3.6	0:00:07
# 160.00	32.0	0.0	3.6	0:00:07
# 161.00	32.2	0.0	3.7	0:00:07
# 162.00	32.4	0.0	3.7	0:00:07
# 163.00	32.6	0.0	3.7	0:00:07
# 164.00	32.8	0.0	3.7	0:00:07
# 165.00	33.0	0.0	3.8	0:00:07
# 166.00	33.2	0.0	3.8	0:00:07
# 167.00	33.4	0.0	3.8	0:00:07
# 168.00	33.6	0.0	3.8	0:00:07
# 169.00	33.8	0.0	3.9	0:00:07
# 170.00	34.0	0.0	3.9	0:00:07
# 171.00	34.2	0.0	3.9	0:00:07
# 172.00	34.4	0.0	3.9	0:00:07
# 173.00	34.6	0.0	3.9	0:00:07
# 174.00	34.8	0.0	3.9	0:00:07
# 175.00	35.0	0.0	4.0	0:00:07
# 176.00	35.2	0.0	4.0	0:00:07
# 177.00	35.4	0.0	4.0	0:00:07
# 178.00	35.6	0.0	4.0	0:00:07
# 179.00	35.8	0.0	4.0	0:00:07
# 180.00	36.0	0.0	4.0	0:00:07
# 181.00	36.2	0.0	4.1	0:00:07
# 182.00	36.4	0.0	4.1	0:00:07
# 183.00	36.6	0.0	4.1	0:00:07
# 184.00	36.8	0.0	4.1	0:00:07
# 185.00	37.0	0.0	4.1	0:00:07
# 186.00	37.2	0.0	4.1	0:00:06
# 187.00	37.4	0.0	4.2	0:00:06
# 188.00	37.6	0.0	4.2	0:00:06
# 189.00	37.8	0.0	4.2	0:00:06
# 190.00	38.0	0.0	4.2	0:00:06
# 191.00	38.2	0.0	4.2	0:00:06
# 192.00	38.4	0.0	4.2	0:00:06
# 193.00	38.6	0.0	4.3	0:00:06
# 194.00	38.8	0.0	4.3	0:00:06
# 195.00	39.0	0.0	4.3	0:00:06
# 196.00	39.2	0.0	4.3	0:00:06
# 197.00	39.4	0.0	4.3	0:00:06
# 198.00	39.6	0.0	4.4	0:00:06
# 199.00	39.8	0.0	4.4	0:00:06
# 200.00	40.0	0.0	4.4	0:00:06
# 201.00	40.2	0.0	4.4	0:00:06
# 202.00	40.4	0.0	4.4	0:00:06
# 203.00	40.6	0.0	4.4	0:00:06
# 204.00	40.8	0.0	4.5	0:00:06
# 205.00	41.0	0.0	4.5	0:00:06
# 206.00	41.2	0.0	4.5	0:00:06
# 207.00	41.4	0.0	4.5	0:00:06
# 208.00	41.6	0.0	4.5	0:00:06
# 209.00	41.8	0.0	4.5	0:00:06
# 210.00	42.0	0.0	4.6	0:00:06
# 211.00	42.2	0.0	4.6	0:00:06
# 212.00	42.4	0.0	4.6	0:00:06
# 213.00	42.6	0.0	4.6	0:00:06
# 214.00	42.8	0.0	4.7	0:00:06
# 215.00	43.0	0.0	4.7	0:00:06
# 216.00	43.2	0.0	4.7	0:00:06
# 217.00	43.4	0.0	4.7	0:00:06
# 218.00	43.6	0.0	4.8	0:00:06
# 219.00	43.8	0.0	4.8	0:00:06
# 220.00	44.0	0.0	4.8	0:00:06
# 221.00	44.2	0.0	4.8	0:00:06
# 222.00	44.4	0.0	4.9	0:00:06
# 223.00	44.6	0.0	4.9	0:00:06
# 224.00	44.8	0.0	4.9	0:00:06
# 225.00	45.0	0.0	4.9	0:00:06
# 226.00	45.2	0.0	4.9	0:00:05
# 227.00	45.4	0.0	5.0	0:00:05
# 228.00	45.6	0.0	5.0	0:00:05
# 229.00	45.8	0.0	5.0	0:00:05
# 230.00	46.0	0.0	5.0	0:00:05
# 231.00	46.2	0.0	5.0	0:00:05
# 232.00	46.4	0.0	5.1	0:00:05
# 233.00	46.6	0.0	5.1	0:00:05
# 234.00	46.8	0.0	5.1	0:00:05
# 235.00	47.0	0.0	5.1	0:00:05
# 236.00	47.2	0.0	5.2	0:00:05
# 237.00	47.4	0.0	5.2	0:00:05
# 238.00	47.6	0.0	5.2	0:00:05
# 239.00	47.8	0.0	5.2	0:00:05
# 240.00	48.0	0.0	5.3	0:00:05
# 241.00	48.2	0.0	5.3	0:00:05
# 242.00	48.4	0.0	5.3	0:00:05
# 243.00	48.6	0.0	5.3	0:00:05
# 244.00	48.8	0.0	5.3	0:00:05
# 245.00	49.0	0.0	5.3	0:00:05
# 246.00	49.2	0.0	5.4	0:00:05
# 247.00	49.4	0.0	5.4	0:00:05
# 248.00	49.6	0.0	5.4	0:00:05
# 249.00	49.8	0.0	5.4	0:00:05
# 250.00	50.0	0.0	5.5	0:00:05
# 251.00	50.2	0.0	5.5	0:00:05
# 252.00	50.4	0.0	5.5	0:00:05
# 253.00	50.6	0.0	5.6	0:00:05
# 254.00	50.8	0.0	5.6	0:00:05
# 255.00	51.0	0.0	5.6	0:00:05
# 256.00	51.2	0.0	5.6	0:00:05
# 257.00	51.4	0.0	5.7	0:00:05
# 258.00	51.6	0.0	5.7	0:00:05
# 259.00	51.8	0.0	5.7	0:00:05
# 260.00	52.0	0.0	5.7	0:00:05
# 261.00	52.2	0.0	5.8	0:00:05
# 262.00	52.4	0.0	5.8	0:00:05
# 263.00	52.6	0.0	5.8	0:00:05
# 264.00	52.8	0.0	5.9	0:00:05
# 265.00	53.0	0.0	5.9	0:00:05
# 266.00	53.2	0.0	5.9	0:00:05
# 267.00	53.4	0.0	5.9	0:00:05
# 268.00	53.6	0.0	5.9	0:00:05
# 269.00	53.8	0.0	6.0	0:00:05
# 270.00	54.0	0.0	6.0	0:00:05
# 271.00	54.2	0.0	6.0	0:00:05
# 272.00	54.4	0.0	6.0	0:00:05
# 273.00	54.6	0.0	6.0	0:00:05
# 274.00	54.8	0.0	6.1	0:00:05
# 275.00	55.0	0.0	6.1	0:00:04
# 276.00	55.2	0.0	6.1	0:00:04
# 277.00	55.4	0.0	6.1	0:00:04
# 278.00	55.6	0.0	6.2	0:00:04
# 279.00	55.8	0.0	6.2	0:00:04
# 280.00	56.0	0.0	6.2	0:00:04
# 281.00	56.2	0.0	6.2	0:00:04
# 282.00	56.4	0.0	6.2	0:00:04
# 283.00	56.6	0.0	6.3	0:00:04
# 284.00	56.8	0.0	6.3	0:00:04
# 285.00	57.0	0.0	6.3	0:00:04
# 286.00	57.2	0.0	6.3	0:00:04
# 287.00	57.4	0.0	6.4	0:00:04
# 288.00	57.6	0.0	6.4	0:00:04
# 289.00	57.8	0.0	6.4	0:00:04
# 290.00	58.0	0.0	6.4	0:00:04
# 291.00	58.2	0.0	6.4	0:00:04
# 292.00	58.4	0.0	6.5	0:00:04
# 293.00	58.6	0.0	6.5	0:00:04
# 294.00	58.8	0.0	6.5	0:00:04
# 295.00	59.0	0.0	6.5	0:00:04
# 296.00	59.2	0.0	6.5	0:00:04
# 297.00	59.4	0.0	6.6	0:00:04
# 298.00	59.6	0.0	6.6	0:00:04
# 299.00	59.8	0.0	6.6	0:00:04
# 300.00	60.0	0.0	6.6	0:00:04
# 301.00	60.2	0.0	6.6	0:00:04
# 302.00	60.4	0.0	6.7	0:00:04
# 303.00	60.6	0.0	6.7	0:00:04
# 304.00	60.8	0.0	6.7	0:00:04
# 305.00	61.0	0.0	6.8	0:00:04
# 306.00	61.2	0.0	6.8	0:00:04
# 307.00	61.4	0.0	6.8	0:00:04
# 308.00	61.6	0.0	6.8	0:00:04
# 309.00	61.8	0.0	6.8	0:00:04
# 310.00	62.0	0.0	6.9	0:00:04
# 311.00	62.2	0.0	6.9	0:00:04
# 312.00	62.4	0.0	6.9	0:00:04
# 313.00	62.6	0.0	6.9	0:00:04
# 314.00	62.8	0.0	6.9	0:00:04
# 315.00	63.0	0.0	7.0	0:00:04
# 316.00	63.2	0.0	7.0	0:00:04
# 317.00	63.4	0.0	7.0	0:00:04
# 318.00	63.6	0.0	7.0	0:00:04
# 319.00	63.8	0.0	7.0	0:00:03
# 320.00	64.0	0.0	7.1	0:00:03
# 321.00	64.2	0.0	7.1	0:00:03
# 322.00	64.4	0.0	7.1	0:00:03
# 323.00	64.6	0.0	7.1	0:00:03
# 324.00	64.8	0.0	7.2	0:00:03
# 325.00	65.0	0.0	7.2	0:00:03
# 326.00	65.2	0.0	7.2	0:00:03
# 327.00	65.4	0.0	7.2	0:00:03
# 328.00	65.6	0.0	7.2	0:00:03
# 329.00	65.8	0.0	7.3	0:00:03
# 330.00	66.0	0.0	7.3	0:00:03
# 331.00	66.2	0.0	7.3	0:00:03
# 332.00	66.4	0.0	7.3	0:00:03
# 333.00	66.6	0.0	7.3	0:00:03
# 334.00	66.8	0.0	7.4	0:00:03
# 335.00	67.0	0.0	7.4	0:00:03
# 336.00	67.2	0.0	7.4	0:00:03
# 337.00	67.4	0.0	7.4	0:00:03
# 338.00	67.6	0.0	7.4	0:00:03
# 339.00	67.8	0.0	7.5	0:00:03
# 340.00	68.0	0.0	7.5	0:00:03
# 341.00	68.2	0.0	7.5	0:00:03
# 342.00	68.4	0.0	7.5	0:00:03
# 343.00	68.6	0.0	7.5	0:00:03
# 344.00	68.8	0.0	7.5	0:00:03
# 345.00	69.0	0.0	7.6	0:00:03
# 346.00	69.2	0.0	7.6	0:00:03
# 347.00	69.4	0.0	7.6	0:00:03
# 348.00	69.6	0.0	7.6	0:00:03
# 349.00	69.8	0.0	7.6	0:00:03
# 350.00	70.0	0.0	7.7	0:00:03
# 351.00	70.2	0.0	7.7	0:00:03
# 352.00	70.4	0.0	7.7	0:00:03
# 353.00	70.6	0.0	7.7	0:00:03
# 354.00	70.8	0.0	7.7	0:00:03
# 355.00	71.0	0.0	7.8	0:00:03
# 356.00	71.2	0.0	7.8	0:00:03
# 357.00	71.4	0.0	7.8	0:00:03
# 358.00	71.6	0.0	7.8	0:00:03
# 359.00	71.8	0.0	7.8	0:00:03
# 360.00	72.0	0.0	7.9	0:00:03
# 361.00	72.2	0.0	7.9	0:00:03
# 362.00	72.4	0.0	7.9	0:00:03
# 363.00	72.6	0.0	8.0	0:00:03
# 364.00	72.8	0.0	8.0	0:00:02
# 365.00	73.0	0.0	8.0	0:00:02
# 366.00	73.2	0.0	8.0	0:00:02
# 367.00	73.4	0.0	8.1	0:00:02
# 368.00	73.6	0.0	8.1	0:00:02
# 369.00	73.8	0.0	8.1	0:00:02
# 370.00	74.0	0.0	8.1	0:00:02
# 371.00	74.2	0.0	8.1	0:00:02
# 372.00	74.4	0.0	8.2	0:00:02
# 373.00	74.6	0.0	8.2	0:00:02
# 374.00	74.8	0.0	8.2	0:00:02
# 375.00	75.0	0.0	8.2	0:00:02
# 376.00	75.2	0.0	8.3	0:00:02
# 377.00	75.4	0.0	8.3	0:00:02
# 378.00	75.6	0.0	8.3	0:00:02
# 379.00	75.8	0.0	8.3	0:00:02
# 380.00	76.0	0.0	8.4	0:00:02
# 381.00	76.2	0.0	8.4	0:00:02
# 382.00	76.4	0.0	8.4	0:00:02
# 383.00	76.6	0.0	8.4	0:00:02
# 384.00	76.8	0.0	8.5	0:00:02
# 385.00	77.0	0.0	8.5	0:00:02
# 386.00	77.2	0.0	8.5	0:00:02
# 387.00	77.4	0.0	8.5	0:00:02
# 388.00	77.6	0.0	8.5	0:00:02
# 389.00	77.8	0.0	8.6	0:00:02
# 390.00	78.0	0.0	8.6	0:00:02
# 391.00	78.2	0.0	8.6	0:00:02
# 392.00	78.4	0.0	8.6	0:00:02
# 393.00	78.6	0.0	8.7	0:00:02
# 394.00	78.8	0.0	8.7	0:00:02
# 395.00	79.0	0.0	8.7	0:00:02
# 396.00	79.2	0.0	8.7	0:00:02
# 397.00	79.4	0.0	8.8	0:00:02
# 398.00	79.6	0.0	8.8	0:00:02
# 399.00	79.8	0.0	8.8	0:00:02
# 400.00	80.0	0.0	8.9	0:00:02
# 401.00	80.2	0.0	8.9	0:00:02
# 402.00	80.4	0.0	8.9	0:00:02
# 403.00	80.6	0.0	9.0	0:00:02
# 404.00	80.8	0.0	9.0	0:00:02
# 405.00	81.0	0.0	9.0	0:00:02
# 406.00	81.2	0.0	9.0	0:00:02
# 407.00	81.4	0.0	9.1	0:00:02
# 408.00	81.6	0.0	9.1	0:00:02
# 409.00	81.8	0.0	9.1	0:00:02
# 410.00	82.0	0.0	9.1	0:00:02
# 411.00	82.2	0.0	9.1	0:00:01
# 412.00	82.4	0.0	9.2	0:00:01
# 413.00	82.6	0.0	9.2	0:00:01
# 414.00	82.8	0.0	9.2	0:00:01
# 415.00	83.0	0.0	9.3	0:00:01
# 416.00	83.2	0.0	9.3	0:00:01
# 417.00	83.4	0.0	9.3	0:00:01
# 418.00	83.6	0.0	9.4	0:00:01
# 419.00	83.8	0.0	9.4	0:00:01
# 420.00	84.0	0.0	9.4	0:00:01
# 421.00	84.2	0.0	9.5	0:00:01
# 422.00	84.4	0.0	9.5	0:00:01
# 423.00	84.6	0.0	9.5	0:00:01
# 424.00	84.8	0.0	9.5	0:00:01
# 425.00	85.0	0.0	9.6	0:00:01
# 426.00	85.2	0.0	9.6	0:00:01
# 427.00	85.4	0.0	9.6	0:00:01
# 428.00	85.6	0.0	9.7	0:00:01
# 429.00	85.8	0.0	9.7	0:00:01
# 430.00	86.0	0.0	9.7	0:00:01
# 431.00	86.2	0.0	9.8	0:00:01
# 432.00	86.4	0.0	9.8	0:00:01
# 433.00	86.6	0.0	9.8	0:00:01
# 434.00	86.8	0.0	9.9	0:00:01
# 435.00	87.0	0.0	9.9	0:00:01
# 436.00	87.2	0.0	9.9	0:00:01
# 437.00	87.4	0.0	10.0	0:00:01
# 438.00	87.6	0.0	10.0	0:00:01
# 439.00	87.8	0.0	10.0	0:00:01
# 440.00	88.0	0.0	10.0	0:00:01
# 441.00	88.2	0.0	10.0	0:00:01
# 442.00	88.4	0.0	10.0	0:00:01
# 443.00	88.6	0.0	10.1	0:00:01
# 444.00	88.8	0.0	10.1	0:00:01
# 445.00	89.0	0.0	10.1	0:00:01
# 446.00	89.2	0.0	10.1	0:00:01
# 447.00	89.4	0.0	10.1	0:00:01
# 448.00	89.6	0.0	10.1	0:00:01
# 449.00	89.8	0.0	10.2	0:00:01
# 450.00	90.0	0.0	10.2	0:00:01
# 451.00	90.2	0.0	10.2	0:00:01
# 452.00	90.4	0.0	10.2	0:00:01
# 453.00	90.6	0.0	10.3	0:00:01
# 454.00	90.8	0.0	10.3	0:00:01
# 455.00	91.0	0.0	10.3	0:00:01
# 456.00	91.2	0.0	10.3	0:00:00
# 457.00	91.4	0.0	10.3	0:00:00
# 458.00	91.6	0.0	10.3	0:00:00
# 459.00	91.8	0.0	10.4	0:00:00
# 460.00	92.0	0.0	10.4	0:00:00
# 461.00	92.2	0.0	10.4	0:00:00
# 462.00	92.4	0.0	10.4	0:00:00
# 463.00	92.6	0.0	10.4	0:00:00
# 464.00	92.8	0.0	10.5	0:00:00
# 465.00	93.0	0.0	10.5	0:00:00
# 466.00	93.2	0.0	10.5	0:00:00
# 467.00	93.4	0.0	10.5	0:00:00
# 468.00	93.6	0.0	10.5	0:00:00
# 469.00	93.8	0.0	10.6	0:00:00
# 470.00	94.0	0.0	10.6	0:00:00
# 471.00	94.2	0.0	10.6	0:00:00
# 472.00	94.4	0.0	10.6	0:00:00
# 473.00	94.6	0.0	10.7	0:00:00
# 474.00	94.8	0.0	10.7	0:00:00
# 475.00	95.0	0.0	10.7	0:00:00
# 476.00	95.2	0.0	10.7	0:00:00
# 477.00	95.4	0.0	10.8	0:00:00
# 478.00	95.6	0.0	10.8	0:00:00
# 479.00	95.8	0.0	10.8	0:00:00
# 480.00	96.0	0.0	10.9	0:00:00
# 481.00	96.2	0.0	10.9	0:00:00
# 482.00	96.4	0.0	10.9	0:00:00
# 483.00	96.6	0.0	10.9	0:00:00
# 484.00	96.8	0.0	11.0	0:00:00
# 485.00	97.0	0.0	11.0	0:00:00
# 486.00	97.2	0.0	11.0	0:00:00
# 487.00	97.4	0.0	11.0	0:00:00
# 488.00	97.6	0.0	11.0	0:00:00
# 489.00	97.8	0.0	11.1	0:00:00
# 490.00	98.0	0.0	11.1	0:00:00
# 491.00	98.2	0.0	11.1	0:00:00
# 492.00	98.4	0.0	11.1	0:00:00
# 493.00	98.6	0.0	11.1	0:00:00
# 494.00	98.8	0.0	11.2	0:00:00
# 495.00	99.0	0.0	11.2	0:00:00
# 496.00	99.2	0.0	11.2	0:00:00
# 497.00	99.4	0.0	11.2	0:00:00
# 498.00	99.6	0.0	11.2	0:00:00
# 499.00	99.8	0.0	11.3	0:00:00
# 500.00	100.0	0.0	11.3	0:00:00
#
#
#   Electrical Solver Timings:
#   --------------------------
#
#   Elliptic          0.00
#     --RHS           0.00
#     --Solve         0.00
#   Parabolic         9.03
#     --RHS           0.94
#     --Solve         8.09
#   ODE               2.16
#   Purkinje          0.00
#   IO                0.08
#
#
# Solution time (sec): 11
# All done!
